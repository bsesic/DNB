# %% [markdown]
# # Metadata
#
# Loads and cleans the Metadata from Compact Memory

# %%
# for the sake of readability remove the warnings
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# ### Bibliotheken importieren

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Metadaten laden
# Die Daten werden aus der Datei `CM_Seiten_Metadaten.csv` geladen.
# Alle Metadaten finden sich in dem Ordner `metadata`.
# Die Spalten sollten mit den richtigen Datentypen geladen werden.

# %%
# Specify the desired data types for each column
dtype_options = {
    'VLID_Seite': 'Int64',
    'OT_PATH': 'str',
    'VLID_Zs': 'Int64',
    'VLID_Parent': 'Int64',
    'Parent Knotentyp': 'str',
    'Parent-Type': 'str',
    'Zs_Caption': 'str',
    'Volume_Caption': 'str',
    'Heft_Caption': 'str',
    'Aufsatz_Caption': 'str',
    'Datum': 'str',  # You'll need to parse this as date later
    'Seite (OT_SORT)': 'Int64',
    'Seite_Caption': 'str',
    'Seitenzahl_Caption': 'str'
}
# Load the CSV file with dtype parameter
df_metadata = pd.read_csv("metadata/CM_Seiten_Metadaten.csv", sep="\t", dtype=dtype_options, parse_dates=['Datum'])

# %% [markdown]
# ## Statistiken über die Metadaten
# Hier erst einmal die Statistiken zu den Metadaten.

# %%
df_metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918165 entries, 0 to 918164
# Data columns (total 14 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   VLID_Seite          918165 non-null  Int64
#  1   OT_PATH             918165 non-null  object
#  2   VLID_Zs             918165 non-null  Int64
#  3   VLID_Parent         918165 non-null  Int64
#  4   Parent Knotentyp    918165 non-null  object
#  5   Parent-Type         918165 non-null  object
#  6   Zs_Caption          918165 non-null  object
#  7   Volume_Caption      918164 non-null  object
#  8   Heft_Caption        823773 non-null  object
#  9   Aufsatz_Caption     163772 non-null  object
#  10  Datum               918165 non-null  object
#  11  Seite (OT_SORT)     918165 non-null  Int64
#  12  Seite_Caption       584763 non-null  object
#  13  Seitenzahl_Caption  814735 non-null  object
# dtypes: Int64(4), object(10)
# memory usage: 101.6+ MB

# %%
df_metadata.describe()
# Out:
#          VLID_Seite       VLID_Zs   VLID_Parent  Seite (OT_SORT)
# count  9.181650e+05  9.181650e+05  9.181650e+05    918165.000000
# mean   3.742243e+06  3.748121e+06  4.144832e+06        27.944801
# std    1.904469e+06  1.972278e+06  2.329042e+06        94.073622
# min    5.259800e+04  5.259600e+04  1.776570e+05         1.000000
# 25%    2.617876e+06  2.583875e+06  2.626174e+06         4.000000
# 50%    3.050373e+06  3.020846e+06  3.054014e+06         8.000000
# 75%    3.980816e+06  4.782723e+06  5.449731e+06        16.000000
# max    1.097610e+07  1.101468e+07  1.101479e+07      3888.000000

# %%
df_metadata.head()
# Out:
#    VLID_Seite                  OT_PATH  VLID_Zs  VLID_Parent Parent Knotentyp  \
# 0       52598  |52596||9443938||52598|    52596      9443938        Metadaten
# 1       52599  |52596||9443938||52599|    52596      9443938        Metadaten
# 2       52600  |52596||9443938||52600|    52596      9443938        Metadaten
# 3       52601  |52596||9443938||52601|    52596      9443938        Metadaten
# 4       52602  |52596||9443938||52602|    52596      9443938        Metadaten
#
#       Parent-Type                                         Zs_Caption  \
# 0  journal volume  ... Bericht ueber den Verein für die Provinz W...
# 1  journal volume  ... Bericht ueber den Verein für die Provinz W...
# 2  journal volume  ... Bericht ueber den Verein für die Provinz W...
# 3  journal volume  ... Bericht ueber den Verein für die Provinz W...
# 4  journal volume  ... Bericht ueber den Verein für die Provinz W...
#
#   Volume_Caption Heft_Caption Aufsatz_Caption       Datum  Seite (OT_SORT)  \
# 0       8 (1835)          NaN             NaN  1835-01-01                1
# 1       8 (1835)          NaN             NaN  1835-01-01                2
# 2       8 (1835)          NaN             NaN  1835-01-01                3
# 3       8 (1835)          NaN             NaN  1835-01-01                4
# 4       8 (1835)          NaN             NaN  1835-01-01                5
#
#   Seite_Caption Seitenzahl_Caption
# 0       [Seite]                NaN
# 1       [Seite]                NaN
# 2       [Seite]                NaN
# 3       Seite 4                  4
# 4       Seite 5                  5

# %%
df_metadata.tail()
# Out:
#         VLID_Seite                        OT_PATH   VLID_Zs  VLID_Parent  \
# 918160     1958923  |11014679||11014793||1958923|  11014679     11014793
# 918161     1958924  |11014679||11014793||1958924|  11014679     11014793
# 918162     1958925  |11014679||11014793||1958925|  11014679     11014793
# 918163     1958926  |11014679||11014793||1958926|  11014679     11014793
# 918164     1958927  |11014679||11014793||1958927|  11014679     11014793
#
#        Parent Knotentyp     Parent-Type                            Zs_Caption  \
# 918160        Metadaten  journal volume  Séance du comité de direction du ...
# 918161        Metadaten  journal volume  Séance du comité de direction du ...
# 918162        Metadaten  journal volume  Séance du comité de direction du ...
# 918163        Metadaten  journal volume  Séance du comité de direction du ...
# 918164        Metadaten  journal volume  Séance du comité de direction du ...
#
#        Volume_Caption Heft_Caption Aufsatz_Caption       Datum  \
# 918160           1914          NaN             NaN  1914-01-01
# 918161           1914          NaN             NaN  1914-01-01
# 918162           1914          NaN             NaN  1914-01-01
# 918163           1914          NaN             NaN  1914-01-01
# 918164           1914          NaN             NaN  1914-01-01
#
#         Seite (OT_SORT) Seite_Caption Seitenzahl_Caption
# 918160               47      Seite 45                 45
# 918161               48       [Seite]                NaN
# 918162               49       [Seite]                NaN
# 918163               50       [Seite]                NaN
# 918164               51       [Seite]                NaN

# %%
df_metadata.sample(5)
# Out:
#         VLID_Seite                                        OT_PATH   VLID_Zs  \
# 912844    10749445                 |10719318||10749704||10749445|  10719318
# 916731    10768923                 |10719318||10772218||10768923|  10719318
# 88583      2408815  |2379786||2379939||2379948||2408665||2408815|   2379786
# 626376     3342840           |3315709||3316186||3316199||3342840|   3315709
# 804061     5367722           |5367336||6488242||5991011||5367722|   5367336
#
#         VLID_Parent Parent Knotentyp     Parent-Type  \
# 912844     10749704        Metadaten  journal volume
# 916731     10772218        Metadaten  journal volume
# 88583       2408665        Metadaten         article
# 626376      3316199        Metadaten   journal issue
# 804061      5991011        Metadaten   journal issue
#
#                          Zs_Caption Volume_Caption          Heft_Caption  \
# 912844                      Aḥiasaf     3 (1895/6)                   NaN
# 916731                      Aḥiasaf    11 (1903/4)                   NaN
# 88583                     Palästina       8 (1835)  Heft 8 (August 1936)
# 626376                     Die Welt       8 (1835)        12 (23.3.1906)
# 804061  Das jüdische Literaturblatt       8 (1835)   No. 12. (23.3.1881)
#
#                                       Aufsatz_Caption       Datum  \
# 912844                                            NaN  1895-01-01
# 916731                                            NaN  1903-01-01
# 88583   Probleme der Jugendverwahrlosung in Palästina  1936-08-01
# 626376                                            NaN  1906-03-23
# 804061                                            NaN  1881-03-23
#
#         Seite (OT_SORT) Seite_Caption Seitenzahl_Caption
# 912844              253     Seite 431                431
# 916731              471     Seite 458                458
# 88583                 2     Seite 398                398
# 626376                8           NaN             (null)
# 804061                4      Seite 48                 48

# %%
df_metadata.corr()
# Out:
#                  VLID_Seite   VLID_Zs  VLID_Parent  Seite (OT_SORT)
# VLID_Seite         1.000000  0.891214     0.840641         0.121274
# VLID_Zs            0.891214  1.000000     0.813594         0.109924
# VLID_Parent        0.840641  0.813594     1.000000         0.099550
# Seite (OT_SORT)    0.121274  0.109924     0.099550         1.000000

# %%
df_metadata.shape
# Out:
# (918165, 14)

# %% [markdown]
# ## Beispiel für die Metadaten
# Damit können wir die Spalten und die Werte in den Metadaten sehen um die Daten besser zu verstehen.

# %%
df_metadata.sample(5)
# Out:
#         VLID_Seite                               OT_PATH  VLID_Zs  \
# 293683     2679589  |2651273||2653156||2653183||2679589|  2651273
# 560381     3239966  |3224737||3225606||3225611||3239966|  3224737
# 210009     2562114  |2554541||2554813||2554816||2562114|  2554541
# 492496     3068133  |3062972||3063062||3063098||3068133|  3062972
# 136759     2479951  |2446951||2448122||2448159||2479951|  2446951
#
#         VLID_Parent Parent Knotentyp    Parent-Type  \
# 293683      2653183        Metadaten  journal issue
# 560381      3225611        Metadaten  journal issue
# 210009      2554816        Metadaten  journal issue
# 492496      3063098        Metadaten  journal issue
# 136759      2448159        Metadaten  journal issue
#
#                                Zs_Caption Volume_Caption  \
# 293683                 Jüdische Rundschau       8 (1835)
# 560381  Allgemeine Zeitung des Judenthums       8 (1835)
# 210009                        Dibre Emeth       8 (1835)
# 492496                       Die Wahrheit       8 (1835)
# 136759                       Der Israelit       8 (1835)
#
#                   Heft_Caption Aufsatz_Caption       Datum  Seite (OT_SORT)  \
# 293683      Heft 27 (4.4.1930)             NaN  1930-04-04                1
# 560381      Heft 4 (22.1.1849)             NaN  1849-01-22                7
# 210009              3-4 (1874)             NaN  1874-01-01               15
# 492496     Heft 36 (13.9.1901)             NaN  1901-09-13                2
# 136759  Heft 39-40 (20.5.1891)             NaN  1891-05-20               10
#
#        Seite_Caption Seitenzahl_Caption
# 293683           NaN             (null)
# 560381      Seite 51                 51
# 210009           NaN             (null)
# 492496           NaN             (null)
# 136759           NaN             (null)

# %% [markdown]
# ## Die Spalten der Metadaten anzeigen

# %%
df_metadata.columns
# Out:
# Index(['VLID_Seite', 'OT_PATH', 'VLID_Zs', 'VLID_Parent', 'Parent Knotentyp',
#        'Parent-Type', 'Zs_Caption', 'Volume_Caption', 'Heft_Caption',
#        'Aufsatz_Caption', 'Datum', 'Seite (OT_SORT)', 'Seite_Caption',
#        'Seitenzahl_Caption'],
#       dtype='object')

# %% [markdown]
# ## Bereinigung der Metadaten
#
# Unnötige Spalten entfernen. Wir benötigen die Informationen zu den Dateien und den Seiten nicht. Diese dienen nur zur Verknüpfung der Metadaten mit den Texten der einzelnen Artikel und Seiten, ist aber für die Analyse nicht relevant.
#
# Das sind: VLID_Seite, OT_PATH, VLID_Zs, VLID_Parent, Parent Knotentyp, Parent-Type, Heft_Caption, Aufsatz_Caption, Seite (OT_SORT), Seite_Caption, Seitenzahl_Caption
#
# Anmerkung: VLID steht für Verlagslösungs-ID, OT für Online-Titelsuche, Zs für Zeitschrift, Heft für Ausgabe, Aufsatz für Artikel, Seite für Seite

# %%
df_metadata.drop(columns=['VLID_Seite', 'OT_PATH', 'VLID_Zs', 'VLID_Parent', 'Parent Knotentyp', 'Parent-Type', 'Seite (OT_SORT)', 'Aufsatz_Caption', 'Seite_Caption', 'Seitenzahl_Caption'], axis=1, inplace=True)

# %% [markdown]
# ### Testen ob die Spalten entfernt wurden

# %%
df_metadata.head()
# Out:
#                                           Zs_Caption Volume_Caption  \
# 0  ... Bericht ueber den Verein für die Provinz W...       8 (1835)
# 1  ... Bericht ueber den Verein für die Provinz W...       8 (1835)
# 2  ... Bericht ueber den Verein für die Provinz W...       8 (1835)
# 3  ... Bericht ueber den Verein für die Provinz W...       8 (1835)
# 4  ... Bericht ueber den Verein für die Provinz W...       8 (1835)
#
#   Heft_Caption       Datum
# 0          NaN  1835-01-01
# 1          NaN  1835-01-01
# 2          NaN  1835-01-01
# 3          NaN  1835-01-01
# 4          NaN  1835-01-01

# %%
df_metadata.sample(5)
# Out:
#                                                Zs_Caption Volume_Caption  \
# 850613  Boletín informativo de la Sociedad Cultural Is...       8 (1835)
# 680594                           Jüdischer Bote vom Rhein       8 (1835)
# 431469                               Wiener Morgenzeitung       8 (1835)
# 114684                                       Der Israelit       8 (1835)
# 792620                                         Der Schild       8 (1835)
#
#                 Heft_Caption       Datum
# 850613       6 (Junio, 1967)  1967-06-01
# 680594       152 (28.4.1922)  1922-04-28
# 431469  Heft 357 (19.1.1920)  1920-01-19
# 114684    Heft 3 (16.1.1861)  1861-01-16
# 792620          9 (8.5.1930)  1930-05-08

# %%
df_metadata.columns
# Out:
# Index(['Zs_Caption', 'Volume_Caption', 'Heft_Caption', 'Datum'], dtype='object')

# %% [markdown]
# ### Liste aller Zeitschriften
#
# Anzahl der Zeitschriften ausgeben lassen und die Liste aller Zeitschriften.

# %%
len(df_metadata['Zs_Caption'].unique())
# Out:
# 308

# %%
df_metadata['Zs_Caption'].unique()
# Out:
# array(['... Bericht ueber den Verein für die Provinz Westfalen zur Bildung von Elementar-Lehrern und Befoerderung von Handwerken und Kuensten unter den Juden',
#        'Führer durch die jüdische Gemeindeverwaltung und Wohlfahrtspflege in Deutschland',
#        'Sechzehnter Bericht über die Religionsschule der jüdischen Gemeinde, womit zu der Sonntag den 26. März in dem Hörsaale der jüdischen Knaben-Schule ... öffentlichen Prüfung ... einladet',
#        '... Bericht ueber den Verein für Westfalen und Rheinprovinz zur Bildung von Elementar-Lehrern und Befoerderung von Handwerken und Kuensten unter den Juden',
#        "... Verwaltungsbericht des Haupt-Grenz-Comité's zu Königsberg i. Pr. für Beseitigung der Nothstände unter den Israeliten West-Rußlands",
#        'Führer durch die jüdische Wohlfahrtspflege in Deutschland',
#        'Bericht der Isr. Religionsschule zu Kiel',
#        'Actes et conférences de la Société des Études Juives',
#        'Jüdischer Almanach', 'Österreichisch-ungarische Cantoren-Zeitung',
#        'Rechenschaftsbericht des Vereins "Gumpertz\'sches Siechenhaus" und der "Minka von Goldschmidt-Rothschild-Stiftung"',
#        '[Verein zur Pflege und Unterstützung israelitischer Kranker Bikkur Cholim, gegründet v. Dr. M. Hirsch. Bericht 4, 1895/97-14,1909]',
#        '... Jahresbericht der Jüdischen Frauenvereinigung e.V. zu Frankfurt a.M.',
#        'Bericht des Pflegamtes des Almosenkastens der israelitischen Gemeinde über dessen Wirksamkeit im Jahre ...',
#        'Jahresbericht der Frauen-Vereinigung der Frankfurt-Loge in Frankfurt a. M.',
#        'Hebraeische Bibliographie', 'Freie jüdische Lehrerstimme',
#        'Mitteilungen des Jüdischen Turn- und Sportvereins Bar-Kochba e.V. Frankfurt a.M.',
#        'Zeitschrift für hebraeische Bibliographie',
#        'Zeitschrift für die Geschichte der Juden in Deutschland',
#        'Altneuland', 'KC-Blätter',
#        'Bericht der Hochschule für die Wissenschaft des Judenthums in Berlin',
#        'Bar Kochba', 'Central-Verein-Zeitung', 'Jeschurun', 'Sulamith',
#        'Im deutschen Reich', 'Der Orient',
#        'Mitteilungen aus dem Verband der Vereine für Jüdische Geschichte und Literatur in Deutschland',
#        'Palästina',
#        'Zeitschrift für die Geschichte der Juden in der Tschechoslowakei',
#        'Illustrirte Monatshefte für die gesammten Interessen des Judenthums',
#        'Jahrbücher für jüdische Geschichte und Litteratur',
#        'Central-Anzeiger für jüdische Litteratur',
#        'Jüdische Zeitschrift für Wissenschaft und Leben',
#        'Jüdische Weltrundschau', 'Blau-Weiss-Blätter',
#        'Neue Nationalzeitung', 'Nationalzeitung', 'Neue Zeitung',
#        'Die Stimme', 'Jüdisches Volksblatt', 'Israelitische Rundschau',
#        'Jüdische Zeitung', 'Der Israelit', 'Der Jude', 'Ben Chananja',
#        'Nachrichtendienst', 'Palästina-Nachrichten',
#        'Mitteilungen der Arbeitsgemeinschaft Jüdisch-Liberaler Jugendvereine Deutschlands',
#        'Nahalat tsevi', 'Dibre Emeth', 'Deborah',
#        'Der Israelit des neunzehnten Jahrhunderts',
#        'Magazin für die Wissenschaft des Judenthums',
#        'Bericht über das Schuljahr ... der Stiftischen Realschule mit Lyzeum der Israelitischen Religionsgesellschaft in Frankfurt am Main',
#        'Freie zionistische Blätter', 'Ost und West',
#        'Kalender und Jahrbuch für Israeliten', 'Jüdisch-liberale Zeitung',
#        'Jüdische Volksstimme', 'Der treue Zionswächter',
#        'Jüdische Presse', 'Mitteilungen zur jüdischen Volkskunde',
#        'Der Jüdische Arbeiter',
#        'Mitteilungen der Gesellschaft für Jüdische Volkskunde',
#        'Jahrbuch der Gesellschaft für Geschichte der Juden in der Čechoslovakischen Republik',
#        'Volk und Land',
#        'Zeitschrift für Demographie und Statistik der Juden',
#        'Jüdische Rundschau', 'Neue jüdische Presse',
#        'Korrespondenzblatt des Vereins zur Gründung und Erhaltung einer Akademie für die Wissenschaft des Judentums',
#        'Judaica', 'Jüdische Arbeits- und Wanderfürsorge', 'Der Anfang',
#        'Der neue Anfang', 'Die neue Welt',
#        "Bericht des Jüdisch-Theologischen Seminars Fraenckel'scher Stiftung",
#        'Bayerische israelitische Gemeindezeitung',
#        'Zeitschrift für die religiösen Interessen des Judenthums',
#        'Mitteilungen des Gesamtarchivs der Deutschen Juden',
#        'Unsere Tribüne', 'KC-Mitteilungen', 'Die Kreatur',
#        'Jüdische Schulzeitung', 'Der jüdische Wille', 'Freie Tribüne',
#        'Esra',
#        'Monatsschrift für Geschichte und Wissenschaft des Judentums',
#        'Der Morgen', 'Neue jüdische Monatshefte', 'Menorah',
#        'Wissenschaftliche Zeitschrift für jüdische Theologie',
#        'Zeitschrift für die Wissenschaft des Judenthums',
#        'Populär-wissenschaftliche Monatsblätter zur Belehrung über das Judenthum für Gebildete aller Confessionen',
#        'Wiener Morgenzeitung', 'Berliner Vereinsbote',
#        "Dr. Bloch's oesterreichische Wochenschrift", 'Die Wahrheit',
#        'Programm', 'Selbst-Emancipation',
#        'Gemeindeblatt der Israelitischen Gemeinde Frankfurt am Main',
#        'Jahrbuch für jüdische Geschichte und Literatur', 'Die Freistatt',
#        'Jahresbericht der Landes-Rabbinerschule in Budapest',
#        'Liberales Judentum', 'Der israelitische Volkslehrer', 'Zion',
#        'Israelitische Annalen', 'Jüdisches Jahrbuch für die Schweiz',
#        'Jahrbuch für die Geschichte der Juden und des Judenthums',
#        'Das Zelt',
#        'Jüdisches Jahrbuch für Sachsen und Adressbuch der Gemeindebehörden, Organisationen und Vereine',
#        'Allgemeine Zeitung des Judenthums', 'Die Welt',
#        'Stenographisches Protokoll der Verhandlungen des … Zionisten-Kongresses … in …',
#        'Jahrbuch der Jüdisch-Literarischen Gesellschaft',
#        'Jüdische Korrespondenz', 'Der junge Jude',
#        'Bericht über die Jacobson-Schule, Realschule mit (Reform-)Realprogymnasium (nach dem Frankfurter Lehrplan) zu Seesen am Harz',
#        'Der jüdische Student', 'Jung Juda', 'Jüdischer Nationalkalender',
#        'Di Yidishe eḳonomiḳ', 'Jerubbaal', 'Jüdischer Bote vom Rhein',
#        'Breslauer jüdisches Gemeindeblatt',
#        'Verwaltungsblatt des Preußischen Landesverbandes Jüdischer Gemeinden',
#        'Jüdisches Wochenblatt', 'Soncino-Blätter',
#        'Jahrbuch für Israeliten', 'Jüdische allgemeine Zeitung',
#        'Bericht über den Zustand der Israelitischen Waisen-Knaben-Anstalt zu Posen',
#        'Lûaḥ', "Bikkūrē hā-'ittīm", 'Kokhve Yitsḥaḳ',
#        'Luaḥ erets Yiśraʾel', 'Zeitschrift für jüdische Wohlfahrtspflege',
#        'Allgemeine Israelitische Wochenschrift', 'Literarishe bleter',
#        'Blätter des Jüdischen Frauenbundes für Frauenarbeit und Frauenbewegung',
#        'Die jüdische Presse', 'Mim-mizraḥ û-mim-maʿarāv',
#        'K.C. Jahrbuch ...', 'Bericht der Großloge für Deutschland',
#        'Haḳedem', 'Das Morgenland', 'Der Sabbath', 'Die Menschenrechte',
#        'Gemeindeblatt der Israelitischen Religionsgemeinde zu Leipzig',
#        'Handwerk und Gewerbe', 'Allgemeine illustrirte Judenzeitung',
#        'Der Aufstieg', "Der bibel'sche Orient",
#        'Bibliographischer Vierteljahresbericht für die jüdische Literatur',
#        'Monatsschrift der Berliner Logen UOBB', 'Freies Blatt',
#        'Das Füllhorn', 'Die Gemeinschaft', 'Die Gegenwart',
#        'Gemeindeblatt der Deutsch-Israelitischen Gemeinde zu Hamburg',
#        'Gemeindeblatt der Israelitischen Religionsgemeinde Dresden',
#        'Herzl-Bund-Blätter', 'Joseph', 'Der israelitische Lehrer',
#        'Die jüdische Frau', 'Jüdische Monatshefte', 'Jüdischer Volksbote',
#        'Jüdisches Gemeindeblatt für das Gebiet der Rheinpfalz',
#        'Gemeinde-Zeitung für die israelitischen Gemeinden Württembergs',
#        'Korrespondenzblatt des Verbandes der Deutschen Juden',
#        'Mitteilungen des Daniel-Bundes', 'Der Schild',
#        'Jüdisches Gemeindeblatt',
#        'Bleṭer far idisher demografye, sṭaṭisṭik un eḳonomiḳ',
#        'Korrespondenzblatt des Centralbüros für Jüdische Auswanderungsangelegenheiten des Hilfsvereins der Deutschen Juden',
#        'Jüdische Turnzeitung', 'Pult und Bühne', 'Rimmōn',
#        'Mitteilungen des Verbandes der Jüdischen Jugendvereine Deutschlands',
#        'Jahresbericht über die Real- u. Volksschule der Israelitischen Gemeinde zu Frankfurt am Main',
#        'Das jüdische Literaturblatt',
#        'Israelitische Wochenschrift für die religiösen und socialen Interessen des Judenthums',
#        'Mitteilungsblatt des Verbandes nationaldeutscher Juden e.V.',
#        'Israelitische Schulzeitung', 'Cultur-almanach', 'Blätter',
#        'Rechenschafts-Bericht',
#        'Gemeindeblatt der Israelitischen Gemeinde Bremen',
#        'Jüdisches Gemeindeblatt für die israelitischen Gemeinden in Württemberg',
#        'Jüdisches Gemeindeblatt für das Gebiet der Hansestadt Hamburg',
#        'Jüdisches Gemeindeblatt Dresden', 'Der jüdische Handwerker',
#        'Israelitische Wochenschrift', 'Jüdisches Familienblatt',
#        'Jüdische Monatshefte für Turnen und Sport',
#        'Jüdische Turn- und Sportzeitung',
#        'Jüdisches Gemeindeblatt und Nachrichtenblatt der Gemeindeverwaltung der Israelitischen Religionsgemeinde zu Leipzig',
#        'Jüdisches Litteratur-Blatt',
#        'Korrespondenzblatt über Auswanderungs- und Siedlungswesen',
#        'Jüdische Auswanderung', 'Der jüdische Arbeitsmarkt',
#        'Der Jugendbund', 'Der nationaldeutsche Jude',
#        'Jüdische Volkszeitung', 'Der Orden Bne Briss', 'Die Bne Briss',
#        'Jahresbericht', 'Jüdische Jugend',
#        'Israelitisches Predigt- und Schul-Magazin', 'Razsvět',
#        'Undzer Worṭ', 'Adressbuch für den jüdischen Buchhandel',
#        'Yediʿot shel Irgun ʿOle Breslau be-Yiśraʾel',
#        'Yediʿot shel Irgun Yotsʾe Shlezyah ʿIlit be-Yiśraʾel',
#        'Yidishe bilder', 'Aus unserer Spielzeit',
#        'Juedischer Almanach für Gross-Rumänien',
#        'Židovská ročenka pre Slovensko', 'Pardes',
#        'Wiener jüdisches Familienblatt',
#        'Literarisches und homiletisches Beiblatt', 'Luaḥ Ḥermon',
#        "Boletín informativo de la Sociedad Cultural Israelita B'ne Jisroel",
#        'Sabbath-Blatt', 'Yedies̀ fun Yidishn Ṿisnshaftlekhn Insṭiṭuṭ',
#        'Bericht der Gesellschaft zur Beförderung des Christenthums unter den Juden in Frankfurt am Main',
#        'Archiv für jüdische Familienforschung, Kunstgeschichte und Museumswesen',
#        'Yor-bukh fun Yidishn yishev in Argenṭine',
#        'Nachricht von der ... Generalversammlung und Jahresfeyer der Frankfurter Gesellschaft zur Beförderung des Christenthums unter den Juden',
#        '... Bericht der Jüdischen Haushaltungsschule zu Frankfurt a.M. für die Zeit vom ... bis ...',
#        'Antisemitisches Jahrbuch für ...',
#        'Bericht der Exekutive der Zionistischen Organisation an den ... Zionistenkongress',
#        'Dirnfurṭer prifilegirṭe tsayṭung', 'Das Band', 'Das Abendland',
#        'Blätter für jüdische Geschichte und Litteratur',
#        'Das jüdische Blatt', 'Wissen und Waffen', 'Das jüdische Echo',
#        '... Jahresbericht der Israelitischen Waisenanstalt zu Frankfut a.M.',
#        'Urwähler-Zeitung',
#        'Mitteilungen des Reichsausschusses der Jüdischen Jugendverbände',
#        'Von deutsch-jüdischer Jugend', "The B'nai B'rith magazine",
#        'Zionist library for boys and girls', 'Alt-Prager Almanach',
#        'Circulare der K.K. Landesregierung im Erzherzogthume Oesterreich unter der Enns',
#        'Kinderblatt', 'Jüdisches Gemeindeblatt für die britische Zone',
#        'Mitteilungen des Israelitischen Lehrervereins für Bayern',
#        'Seite der Jugend', 'Jüdische Zeitung für Ostdeutschland',
#        'Der jüdische Herold', 'Jungjüdischer Wanderer',
#        'Mitteilungs-Blatt des Jüdischen Volksrats Posen', 'Der Zug',
#        'Die Jüdische Gemeinde',
#        'Mitteilungsblatt des Landesverbandes israelitischer Religionsgemeinden Hessens',
#        "B'nai B'rith",
#        'Mitteilungen des Verbandes Bayerischer Israelitischer Gemeinden',
#        'Ha- Meʾasef', 'Milgroym',
#        'Mittheilungen der Oesterreichisch-Israelitischen Union',
#        'Vereins-Mitteilungen des jüdischen Religions-Vereins Friedenau, Steglitz u. Umgegend, e.V., des jüdischen Frauen-Vereins der südwestl. Vororte, des jüdischen Jugend-Vereins der südwestl. Vororte, des religiösen Vereins zu Steglitz',
#        'Jüdische Nachrichten', 'Israelitischer Reichs-Bote',
#        'Israelitisches Predigt-Magazin', 'Jüdische Wochenschau',
#        'Das Echo', 'Central-Vereins-Dienst', 'Das jüdische Centralblatt',
#        'Der israelitische Bote', 'Israelitischer Jugendfreund',
#        'Blätter der Jüdischen Buchvereinigung',
#        'Gross-Berliner C.V.-Post',
#        'Einladungsschrift zu der auf den ... festgesetzten öffentlichen Prüfung der Real- und Volksschule der Israelitischen Gemeinde',
#        'Einladungsschrift zu der am ... stattfindenden öffentlichen Prüfung der Real- und Volksschule der Israelitischen Gemeinde zu Frankfurt am Main',
#        'Einladungsschrift zu der öffentlichen Prüfung der Bürger- und Realschule der Israelitischen Gemeinde',
#        'Einladungsschrift zu der auf den ... statthabenden öffentlichen Prüfung in der Real- und Volksschule der Israelitischen Gemeinde',
#        'Einladung zu der am ... statthabenden öffentlichen Prüfung in der Real- und Volksschule der Israelitischen Gemeinde',
#        'Einladungsschrift zu der am ... statt habenden öffentlichen Prüfung in der Bürger- und Realschule der Israelitischen Gemeinde',
#        'Einladung zu der auf den ... festgesetzten öffentlichen Prüfung in der Bürger- und Realschule der Israelitischen Gemeinde',
#        'Einladung zu der am ... statthabenden öffentlichen Prüfung in der Bürger- und Realschule der Israelitischen Gemeinde',
#        'Einladungsschrift zu der auf den ... statthabenden öffentlichen Prüfung in der Israelitischen Realschule',
#        'Einladungsschrift zu der auf den ... festgesetzten öffentlichen Prüfung der Bürger- und Realschule der Israelitischen Gemeinde',
#        'Einladungsschrift zu der am ... stattfindenden öffentlichen Prüfung der Bürger- und Real-Schule der Israel. Gemeinde',
#        'Einladungsschrift zu der am stattfindenden öffentlichen Prüfung der Volks- und Realschule der Israelitischen Gemeinde',
#        'Monatschrift der Oesterreichisch-Israelitischen Union',
#        'Statuten für die "Achawa", Verein zur Unterstützung Hilfsbedürftiger Israelitischer Lehrer, Lehrer-Witwen und -Waisen in Deutschland',
#        'Financial report of the Palestine Zionist Executive',
#        'Report to the ... Zionist Congress and to the Council of the Jewish Agency in ...',
#        'Bericht des Departements für Landwirtschaftliche Kolonisation über die Jahre ... an den ... Zionisten-Kongress und die ... Tagung des Council der Jewish Agency',
#        'Political report of the Executive of the Jewish Agency submitted to the ... Zionist Congress and the ... session of the Council of the Jewish Agency',
#        'Mitteilungen des Jüdischen Lehrervereins für Bayern',
#        'Bericht des Vorstandes der Israelitischen Wohlfahrtskasse zu Frankfurt a.M. (früher "Israelitische Sterbekasse")',
#        'Jüdischer Volksfreund', 'Zuwachsverzeichnis für die Jahre ...',
#        'Beilage in Wiedergutmachungsfragen',
#        'Bericht des Vorstandes der Israelitischen Sterbekasse zu Frankfurt am Main',
#        'Gemeindeblatt für die Jüdischen Gemeinden Preussens',
#        'Jüdisches Gemeindeblatt für die Synagogen-Gemeinden in Preussen und Norddeutschland',
#        'Illustrirter jüdischer Familienkalender',
#        'Jahresbericht der Jugendgruppe (begründet von der Frauenvereinigung der Frankfurt-Loge) in Frankfurt a. M. für den Zeitraum vom ...',
#        'Jüdisches Gemeindeblatt für den Verband der Kultusgemeinden in Bayern und die Kultusgemeinden München, Augsburg, Bamberg, Würzburg',
#        'Aḥiasaf', 'Séance du comité de direction du ...'], dtype=object)

# %% [markdown]
# ## Duplikate entfernen
# Durch die Spalte ZS-Caption sieht man, dass einige Zeitschriften mehrfach vorkommen. Diese Duplikate müssen entfernt werden.
#
# Es kommen dann immer noch die Zeitschriften mehrfach vor aber mit unterschiedlichen Heft- und Volumenangaben. Das ist in Ordnung, da es sich um unterschiedliche Ausgaben handelt.

# %%
cols_to_check = ['Zs_Caption', 'Volume_Caption', 'Heft_Caption', 'Datum']

# Remove duplicates from specific columns
df_metadata = df_metadata.drop_duplicates(subset=cols_to_check)

# %%
df_metadata.shape[0]
# Out:
# 55300

# %%
df_metadata.sample(5)
# Out:
#                       Zs_Caption Volume_Caption           Heft_Caption  \
# 764400      Handwerk und Gewerbe       8 (1835)  1. u. 2. Oktober-Heft
# 257374           Jüdische Presse       8 (1835)         17 (23.4.1926)
# 776487  Der israelitische Lehrer       8 (1835)         45 (5.10.1863)
# 740423       Die jüdische Presse       8 (1835)         11 (18.3.1886)
# 100752      Neue Nationalzeitung       8 (1835)    Heft 32 (14.8.1908)
#
#              Datum
# 764400  1915-10-01
# 257374  1926-04-23
# 776487  1863-10-05
# 740423  1886-01-01
# 100752  1908-08-14

# %% [markdown]
# ### Show the dataframe

# %%
df_metadata
# Out:
#                                                Zs_Caption  \
# 0       ... Bericht ueber den Verein für die Provinz W...
# 93      Führer durch die jüdische Gemeindeverwaltung u...
# 687     Sechzehnter Bericht über die Religionsschule d...
# 724     ... Bericht ueber den Verein für Westfalen und...
# 881     ... Verwaltungsbericht des Haupt-Grenz-Comité'...
# ...                                                   ...
# 917902               Séance du comité de direction du ...
# 917948               Séance du comité de direction du ...
# 918012               Séance du comité de direction du ...
# 918068               Séance du comité de direction du ...
# 918114               Séance du comité de direction du ...
#
#               Volume_Caption Heft_Caption       Datum
# 0                   8 (1835)          NaN  1835-01-01
# 93                   1932-33          NaN  1932-01-01
# 687                        0          NaN  1871-01-01
# 724                 9 (1836)          NaN  1836-01-01
# 881     Erstes Semester 1870          NaN  1870-01-01
# ...                      ...          ...         ...
# 917902                  1910          NaN  1910-01-01
# 917948                  1911          NaN  1911-01-01
# 918012                  1912          NaN  1912-01-01
# 918068                  1913          NaN  1913-01-01
# 918114                  1914          NaN  1914-01-01
#
# [55300 rows x 4 columns]

# %% [markdown]
# So viele Zeitschriften sind dennoch mehrfach vorhanden.

# %%
# count duplicate rows in 'Zs_Caption'
df_metadata['Zs_Caption'].duplicated().sum()
# Out:
# 54992

# %% [markdown]
# ## Clean up the titles
#
# Wir ersetzen die Zeichen `...` durch `*` und entfernen führende und abschließende Leerzeichen.
# Die ... waren in den Titeln wohl Platzhalter für Datumsangaben, die nicht mehr vorhanden sind.
# Durch das Ersetzen mit einer Wildcard können wir die Titel besser finden.

# %%
#df_metadata['Zs_Caption'] = df_metadata['Zs_Caption'].str.replace("\.\.\.", "*", regex=True)
df_metadata['Zs_Caption'] = df_metadata['Zs_Caption'].str.strip()

# %%
# remove all nan values
df_metadata = df_metadata.fillna("")
df_metadata = df_metadata.replace('nan', '')
df_metadata

# %% [markdown]
# # Bereinigung der Spalten

# %% [markdown]
# ## Jahr aus Datum extrahieren

# %%
# take the Datum as datetime and extract the year
df_metadata['Datum'].replace({'0001-01-07': '1896-01-07'}, inplace=True) # ist ein Fehler in den Daten
df_metadata['Datum'] = pd.to_datetime(df_metadata['Datum'], errors='coerce')
df_metadata['Year'] = pd.to_numeric(df_metadata['Datum'].dt.year)
df_metadata.sample(5)
# Out:
#                     Zs_Caption Volume_Caption         Heft_Caption      Datum  \
# 83759                Palästina       8 (1835)             Heft 6-7 1927-01-01
# 292149      Jüdische Rundschau       8 (1835)  Heft 14 (17.2.1928) 1928-02-17
# 254381  Der treue Zionswächter       8 (1835)       24 (15.6.1847) 1847-06-15
# 508578            Die Wahrheit       8 (1835)  Heft 34 (19.8.1932) 1932-08-19
# 216822  Central-Verein-Zeitung       8 (1835)   Heft 6 (Juni 1926) 1926-06-01
#
#           Year
# 83759   1927.0
# 292149  1928.0
# 254381  1847.0
# 508578  1932.0
# 216822  1926.0

# %%
df_metadata
# Out:
#                                                Zs_Caption  \
# 0       ... Bericht ueber den Verein für die Provinz W...
# 93      Führer durch die jüdische Gemeindeverwaltung u...
# 687     Sechzehnter Bericht über die Religionsschule d...
# 724     ... Bericht ueber den Verein für Westfalen und...
# 881     ... Verwaltungsbericht des Haupt-Grenz-Comité'...
# ...                                                   ...
# 917902               Séance du comité de direction du ...
# 917948               Séance du comité de direction du ...
# 918012               Séance du comité de direction du ...
# 918068               Séance du comité de direction du ...
# 918114               Séance du comité de direction du ...
#
#               Volume_Caption Heft_Caption      Datum    Year
# 0                   8 (1835)          NaN 1835-01-01  1835.0
# 93                   1932-33          NaN 1932-01-01  1932.0
# 687                        0          NaN 1871-01-01  1871.0
# 724                 9 (1836)          NaN 1836-01-01  1836.0
# 881     Erstes Semester 1870          NaN 1870-01-01  1870.0
# ...                      ...          ...        ...     ...
# 917902                  1910          NaN 1910-01-01  1910.0
# 917948                  1911          NaN 1911-01-01  1911.0
# 918012                  1912          NaN 1912-01-01  1912.0
# 918068                  1913          NaN 1913-01-01  1913.0
# 918114                  1914          NaN 1914-01-01  1914.0
#
# [55300 rows x 5 columns]

# %% [markdown]
# ## XXX Ausgabe der Zeitschriften

# %%
df_metadata['Volume_Caption'].unique().tolist()

# %%
# Convert 'Year' column to string for comparison
df_metadata['Year'] = df_metadata['Year'].astype(str)

# Initialize an empty list to store tuples of values and corresponding years
values_and_years_to_print = []

# Iterate over each row in the DataFrame
for index, row in df_metadata.iterrows():
    # Check if the year from 'Year' column is included in the 'Volume_Caption' column
    if row['Year'] not in row['Volume_Caption']:
        # If the year is not included, append a tuple of (value, year) to the list
        values_and_years_to_print.append((row['Volume_Caption'], row['Year']))

# Print the values and corresponding years
for value, year in values_and_years_to_print:
    print(f"Volume Caption: {value}, Year: {year}")

# %% [markdown]
# ## XXX Ausgabe der Hefte

# %%
# list all unique values in 'Heft_Caption'
df_metadata['Heft_Caption'].unique().tolist()

# %%
# Extract the year from 'Heft_Caption' column
year_regex = r'(?:Heft \d{4}\D*)(\d{4})|\b(\d{4})\b'
extracted_years = df_metadata['Heft_Caption'].str.extract(year_regex)

# Apply lambda function to handle the extracted year values
df_metadata['Heft_Year'] = extracted_years.apply(lambda x: x[0] if not pd.isnull(x[0]) else x[1], axis=1)

df_metadata.sample(5)

# %% [markdown]
# ## XXX Check if the years in 'Heft_Year' and 'Year' are different

# %%
# Check if 'Heft_Year' and 'Year' contain different values
#  Replace non-finite values in 'Year' with an empty string
df_metadata['Year'].fillna("", inplace=True)

# Convert 'Year' to string
df_metadata['Year'] = df_metadata['Year'].astype(str)
df_metadata['Heft_Year'] = df_metadata['Heft_Year'].astype(str)

# Check if 'Heft_Year' and 'Year' contain different values
different_values_mask = df_metadata['Heft_Year'] != df_metadata['Year']

# Print rows where the values are different
df_metadata[different_values_mask]

# %%
df_metadata['Year'].dtype

# %% [markdown]
# ## Aggregation der Metadaten

# %% [markdown]
# Die Title werden zusammengeführt und die frühesten und spätesten Jahre und Daten ermittelt.
# Lücken werden dabei nicht berücksichtigt.
# Die Daten aus der ZDB sind auch nicht so detailiert, dass sie die einzelnen Ausgaben und Jahrgänge enthalten.

# %%
# Step 1: Create a new DataFrame with unique values from 'Zs_Caption'
unique_titles_df = pd.DataFrame(df_metadata['Zs_Caption'].unique(), columns=['Zs_Caption'])

# Step 2-4: Iterate over each unique title, find earliest and latest year, and store in a new DataFrame
result_rows = []
for title in unique_titles_df['Zs_Caption']:
    # Filter df_metadata for the current title
    title_metadata = df_metadata[df_metadata['Zs_Caption'] == title]
    # Find the earliest and latest year
    year_from = title_metadata['Year'].min()
    year_to = title_metadata['Year'].max()
    # Append the result as a new row
    result_rows.append({'Zs_Caption': title, 'Year_From': year_from, 'Year_To': year_to})

# Create a new DataFrame with the results
result_df = pd.DataFrame(result_rows)

# Convert string representations of "nan" to actual NaN values
result_df['Year_To'] = result_df['Year_To'].replace('nan', np.nan)

# Replace NaN values and missing values in 'Year_To' with the corresponding values from 'Year_From'
result_df['Year_To'].fillna(result_df['Year_From'], inplace=True)

result_df['Year_From'] = pd.to_numeric(result_df['Year_From'], errors='coerce').fillna(0).astype(int)
result_df['Year_To'] = pd.to_numeric(result_df['Year_To'], errors='coerce').fillna(0).astype(int)

# Print the resulting DataFrame
result_df
# Out:
#                                             Zs_Caption  Year_From  Year_To
# 0    ... Bericht ueber den Verein für die Provinz W...       1835     1835
# 1    Führer durch die jüdische Gemeindeverwaltung u...       1932     1932
# 2    Sechzehnter Bericht über die Religionsschule d...       1871     1871
# 3    ... Bericht ueber den Verein für Westfalen und...       1836     1836
# 4    ... Verwaltungsbericht des Haupt-Grenz-Comité'...       1870     1870
# ..                                                 ...        ...      ...
# 303            Illustrirter jüdischer Familienkalender       1881     1907
# 304  Jahresbericht der Jugendgruppe (begründet von ...       1913     1913
# 305  Jüdisches Gemeindeblatt für den Verband der Ku...       1937     1938
# 306                                            Aḥiasaf       1893     1922
# 307               Séance du comité de direction du ...       1907     1914
#
# [308 rows x 3 columns]

# %%
# Iterate over each unique title in the 'Zs_Caption' column
for title in unique_titles_df['Zs_Caption']:
    # Filter df_metadata for the current title
    title_metadata = df_metadata[df_metadata['Zs_Caption'] == title]
    # Find the earliest and latest date
    date_from = title_metadata['Datum'].min()
    date_to = title_metadata['Datum'].max()
    # Append the result as a new row to the existing results_df
    result_df = result_df.append({'Zs_Caption': title, 'Date_From': date_from, 'Date_To': date_to}, ignore_index=True)

# Step 5: Replace NaN values in 'Date_To' with values from 'Date_From'
result_df['Date_To'].fillna(result_df['Date_From'], inplace=True)

# Step 6: Convert 'Date_From' and 'Date_To' to datetime
result_df['Date_From'] = pd.to_datetime(result_df['Date_From'])
result_df['Date_To'] = pd.to_datetime(result_df['Date_To'])

# Print the resulting DataFrame
result_df
# Out:
#                                             Zs_Caption  Year_From  Year_To  \
# 0    ... Bericht ueber den Verein für die Provinz W...     1835.0   1835.0
# 1    Führer durch die jüdische Gemeindeverwaltung u...     1932.0   1932.0
# 2    Sechzehnter Bericht über die Religionsschule d...     1871.0   1871.0
# 3    ... Bericht ueber den Verein für Westfalen und...     1836.0   1836.0
# 4    ... Verwaltungsbericht des Haupt-Grenz-Comité'...     1870.0   1870.0
# ..                                                 ...        ...      ...
# 611            Illustrirter jüdischer Familienkalender        NaN      NaN
# 612  Jahresbericht der Jugendgruppe (begründet von ...        NaN      NaN
# 613  Jüdisches Gemeindeblatt für den Verband der Ku...        NaN      NaN
# 614                                            Aḥiasaf        NaN      NaN
# 615               Séance du comité de direction du ...        NaN      NaN
#
#      Date_From    Date_To
# 0          NaT        NaT
# 1          NaT        NaT
# 2          NaT        NaT
# 3          NaT        NaT
# 4          NaT        NaT
# ..         ...        ...
# 611 1881-01-01 1907-01-01
# 612 1913-01-01 1913-01-01
# 613 1937-08-01 1938-11-01
# 614 1893-01-01 1922-01-01
# 615 1907-01-01 1914-01-01
#
# [616 rows x 5 columns]

# %%
# Merge unique_titles_df with df_metadata to get dates for each Zs_Caption
merged_df = pd.merge(unique_titles_df, df_metadata[['Zs_Caption', 'Datum']], on='Zs_Caption', how='left')

# Group by Zs_Caption and aggregate to find the earliest and latest dates
aggregated_df = merged_df.groupby('Zs_Caption').agg(Date_From=('Datum', 'min'), Date_To=('Datum', 'max')).reset_index()

# Replace NaN values in 'Date_To' with values from 'Date_From'
aggregated_df['Date_To'].fillna(aggregated_df['Date_From'], inplace=True)

# Convert 'Date_From' and 'Date_To' to datetime
aggregated_df['Date_From'] = pd.to_datetime(aggregated_df['Date_From'])
aggregated_df['Date_To'] = pd.to_datetime(aggregated_df['Date_To'])

# Update result_df with the aggregated dates
result_df.update(aggregated_df)

# Print the resulting DataFrame
result_df
# Out:
#                                             Zs_Caption  Year_From  Year_To  \
# 0    ... Bericht der Jüdischen Haushaltungsschule z...     1835.0   1835.0
# 1    ... Bericht ueber den Verein für Westfalen und...     1932.0   1932.0
# 2    ... Bericht ueber den Verein für die Provinz W...     1871.0   1871.0
# 3    ... Jahresbericht der Israelitischen Waisenans...     1836.0   1836.0
# 4    ... Jahresbericht der Jüdischen Frauenvereinig...     1870.0   1870.0
# ..                                                 ...        ...      ...
# 611            Illustrirter jüdischer Familienkalender        NaN      NaN
# 612  Jahresbericht der Jugendgruppe (begründet von ...        NaN      NaN
# 613  Jüdisches Gemeindeblatt für den Verband der Ku...        NaN      NaN
# 614                                            Aḥiasaf        NaN      NaN
# 615               Séance du comité de direction du ...        NaN      NaN
#
#      Date_From    Date_To
# 0   1821-01-01 1910-01-01
# 1   1836-01-01 1836-01-01
# 2   1835-01-01 1835-01-01
# 3   1915-01-01 1917-01-01
# 4   1855-01-01 1922-01-01
# ..         ...        ...
# 611 1881-01-01 1907-01-01
# 612 1913-01-01 1913-01-01
# 613 1937-08-01 1938-11-01
# 614 1893-01-01 1922-01-01
# 615 1907-01-01 1914-01-01
#
# [616 rows x 5 columns]

# %% [markdown]
# ### Löschen von NaN-Werten

# %%
df_metadata = df_metadata.fillna("")
df_metadata = df_metadata.replace('nan', '')

result_df = result_df.fillna("")
result_df = result_df.replace('nan', '')

# %% [markdown]
# ## Speichern der aggregierten Metadaten

# %%
result_df.to_csv("metadata/CM_Seiten_Metadaten_aggregated.csv", sep="\t", index=False)

# %% [markdown]
# # Save the cleaned metadata

# %%
df_metadata.to_csv("metadata/CM_Seiten_Metadaten_cleaned.csv", sep="\t", index=False)

# %% [markdown]
# ### Speichern der Zeitschriftentitel in einer Textdatei

# %%
with open("metadata/journal_titles.txt", "w") as f:
    for title in df_metadata['Zs_Caption'].unique():
        # remove leading and trailing whitespaces
        title = title.strip()
        f.write(f"{title}\n")
